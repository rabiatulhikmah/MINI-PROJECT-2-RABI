# %% [markdown]
# # BUSINESS UNDERSTANDING

# %% [markdown]
# **Judul**: Rekomendasi Produk Fashion Berdasarkan Rentang Harga dan Merek

# %% [markdown]
# ## Business Objective
# Tujuan utama proyek ini adalah meningkatkan penjualan dan kepuasan pelanggan di platform e-commerce melalui sistem rekomendasi produk yang mempertimbangkan preferensi merek dan rentang harga. Dengan memahami pola pembelian konsumen, proyek ini berupaya menawarkan pengalaman belanja yang lebih personal dan relevan. Selain itu, inisiatif ini diharapkan dapat mengoptimalkan strategi pemasaran dan meningkatkan loyalitas pelanggan terhadap platform.

# %% [markdown]
# ## Assess Situasion
# Industri fashion e-commerce bersifat sangat kompetitif dengan beragam merek dan variasi harga. Pelanggan sering merasa kesulitan menemukan produk yang sesuai dengan preferensi mereka. Dataset yang digunakan berisi informasi penting seperti nama produk, merek, harga, deskripsi, dan kategori. Namun, tantangan utamanya adalah mengolah data ini agar mampu memberikan rekomendasi yang tepat tanpa membuat pengguna merasa jenuh atau kewalahan.
# Selain itu, perubahan tren dan perilaku pelanggan yang dinamis membutuhkan sistem rekomendasi yang adaptif. Oleh karena itu, diperlukan analisis mendalam mengenai hubungan antara preferensi merek dan rentang harga untuk memastikan rekomendasi tetap relevan seiring waktu.

# %% [markdown]
# ## Data Mining Goals
# Tujuan dari data mining dalam proyek ini adalah memahami preferensi pelanggan terhadap merek dan rentang harga tertentu. Dengan menganalisis pola pembelian, kita bisa mengetahui produk mana yang paling sering dipilih berdasarkan harga dan merek. Selain itu, pengelompokan pelanggan yang memiliki kesukaan serupa dapat membantu dalam membuat rekomendasi yang lebih relevan. Pendekatan ini juga bertujuan untuk meningkatkan pengalaman belanja dengan memberikan saran produk yang sesuai dan lebih personal bagi setiap pengguna.

# %% [markdown]
# ## Project Plan
#
#
# 1.   **Eksplorasi Data:**
# Mulai dengan membersihkan data dari duplikasi atau informasi yang kurang relevan. Lalu, analisis harga dan merek mana yang paling populer menggunakan grafik sederhana seperti bar chart dan histogram. Ini bertujuan agar kita bisa paham pola dasar dari data yang tersedia.
# 2.   **Pemodelan:**
# Buat model rekomendasi yang fokus pada harga dan merek. Misalnya, menggunakan content-based filtering untuk rekomendasi produk serupa berdasarkan deskripsi, merek, dan harga. Jika memungkinkan, kombinasikan dengan collaborative filtering jika ada data perilaku pengguna.
# 3. **Evaluasi:**
# Uji model rekomendasi dengan data yang ada untuk memastikan akurasinya. Bisa pakai metrik sederhana seperti berapa kali rekomendasi diklik atau dibeli. Evaluasi ini penting biar kita tahu modelnya bener-bener efektif atau belum.
# 4. **Peluncuran:**
# Terapkan rekomendasi secara bertahap, mulai dari kelompok pengguna kecil dulu. Kumpulkan umpan balik untuk perbaikan sebelum diluncurkan secara penuh. Dengan cara ini, risiko kesalahan bisa diminimalkan dan rekomendasi bisa terus ditingkatkan sesuai kebutuhan pelanggan.

# %% [markdown]
# # DATA UNDERSTANDING & DATA PREPARATION

# %% [markdown]
# Dataset yang digunakan dalam proyek ini berasal dari:
# - Nama Dataset: Fashion Product Dataset
# - Sumber: Kaggle
# - Link: https://www.kaggle.com/datasets/shivamb/fashion-clothing-products-catalog
# - Deskripsi: Dataset ini berisi informasi tentang produk fashion, termasuk nama produk, merek, harga, deskripsi, dan kategori.

# %%
import pandas as pd

# Membaca data dari file CSV
df = pd.read_csv("myntra_products_catalog.csv")
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex        11745          7
# 1       EthnoVogue   Women         5810          7
# 2           SPYKAR   Women          899          7
# 3          Raymond     Men         5599          5
# 4             Parx     Men          759          5
# ...            ...     ...          ...        ...
# 12486   Pepe Jeans     Men         1299          7
# 12487        Mochi   Women         1990          5
# 12488   612 league   Girls          602          4
# 12489      Bvlgari     Men         8950          2
# 12490   Pepe Jeans     Men          799          5
#
#                                              Description PrimaryColor
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
# [12491 rows x 8 columns]

# %% [markdown]
# ## **Data Cleaning**

# %% [markdown]
# Data cleaning merupakan proses menghapus atau memodifikasi data yang tidak lengkap, duplikat, tidak akurat, dan salah format. Data-data tersebut dihapus atau dimodifikasi untuk memastikan data yang sedang diolah adalah data berkualitas agar dapat menghasilkan keputusan yang lebih akurat.

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Missing Values adalah sebuah kondisi dimana data hilang atau tidak terbaca.

# %% [markdown]
# #### Melihat Missing Values

# %% [markdown]
# Melakukan pengecekan missing values perkolom dalam bentuk presentase, guna mendukung pengambilan keputusan pada nilai yang kosong

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# ProductID       0.000000
# ProductName     0.000000
# ProductBrand    0.000000
# Gender          0.000000
# Price (INR)     0.000000
# NumImages       0.000000
# Description     0.000000
# PrimaryColor    7.157153
# dtype: float64

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom Product Brand

# %%
df[df['ProductBrand'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, ProductBrand, Gender, Price (INR), NumImages, Description, PrimaryColor]
# Index: []

# %% [markdown]
# Melakukan pengecekan nilai kosong pada kolom Price (INR)

# %%
df[df['Price (INR)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, ProductBrand, Gender, Price (INR), NumImages, Description, PrimaryColor]
# Index: []

# %% [markdown]
# #### Mengatasi Missing Values

# %% [markdown]
# Melakukan Imputasi

# %% [markdown]
# Di sini kita akan melakukan imputasi pada kolom PrimaryColor dikarenakan data yang hilang pada kolom ini berada di angka 7.15%

# %%
df['PrimaryColor'].dropna().describe()
# Out:
# count     11597
# unique       27
# top        Blue
# freq       3443
# Name: PrimaryColor, dtype: object

# %%
df['PrimaryColor'] = df['PrimaryColor'].fillna(df['PrimaryColor'].mode()[0])

# %% [markdown]
# ### Duplicated Values

# %% [markdown]
# Duplicated Values adalah sebuah kondisi dimana ada data yang muncul beberapa kali dalam satu data set.

# %% [markdown]
# Cara penanganannya adalah dengan menghapus semua duplikasi

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, ProductBrand, Gender, Price (INR), NumImages, Description, PrimaryColor]
# Index: []

# %% [markdown]
# Alhamdulillah bang dan mba, data saya tidak ada yang terduplikat

# %% [markdown]
# ### Outliers

# %% [markdown]
# Outliers adalah nilai yang jauh berbeda dari nilai lainnya dalam dataset. Nilai Outlier bisa jauh lebih rendah atau lebih tinggi. Outlier bisa terjadi karena berbagai alasan seperti faktor kesalahan maupun kejadian lain yang tidak terduga.

# %% [markdown]
# Melakukan pengecekan outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom        Persentase Outliers
# ProductID               2.529821
# Price (INR)             9.342727
# NumImages              42.886879

# %%
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex        11745          7
# 1       EthnoVogue   Women         5810          7
# 2           SPYKAR   Women          899          7
# 3          Raymond     Men         5599          5
# 4             Parx     Men          759          5
# ...            ...     ...          ...        ...
# 12486   Pepe Jeans     Men         1299          7
# 12487        Mochi   Women         1990          5
# 12488   612 league   Girls          602          4
# 12489      Bvlgari     Men         8950          2
# 12490   Pepe Jeans     Men          799          5
#
#                                              Description PrimaryColor
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...         Blue
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
# [12491 rows x 8 columns]

# %% [markdown]
# Melakukan Imputasi

# %%
columns_to_impute = ["ProductID", "Price (INR)"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# <ipython-input-13-15d3a1a56dd4>:11: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[10017413. 10016283. 10009781. ... 10261607. 10266621. 10265199.]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# Melakukan pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom        Persentase Outliers
# ProductID               0.000000
# Price (INR)             0.000000
# NumImages              42.886879

# %%
df
# Out:
#         ProductID                                        ProductName  \
# 0      10017413.0  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1      10016283.0  EthnoVogue Women Beige & Grey Made to Measure ...
# 2      10009781.0  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3      10015921.0  Raymond Men Blue Self-Design Single-Breasted B...
# 4      10017833.0  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...           ...                                                ...
# 12486  10262843.0  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487  10261721.0                 Mochi Women Gold-Toned Solid Heels
# 12488  10261607.0  612 league Girls Navy Blue & White Printed Reg...
# 12489  10266621.0  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490  10265199.0  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex         2774          7
# 1       EthnoVogue   Women         2774          7
# 2           SPYKAR   Women          899          7
# 3          Raymond     Men         2774          5
# 4             Parx     Men          759          5
# ...            ...     ...          ...        ...
# 12486   Pepe Jeans     Men         1299          7
# 12487        Mochi   Women         1990          5
# 12488   612 league   Girls          602          4
# 12489      Bvlgari     Men         2774          2
# 12490   Pepe Jeans     Men          799          5
#
#                                              Description PrimaryColor
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...         Blue
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
# [12491 rows x 8 columns]

# %% [markdown]
# ### Incosistent Value

# %% [markdown]
# Alhamdulillah bang dan mba dari data saya ini tidak ada yang perlu dicari inconsistent valuenya.

# %%
df
# Out:
#         ProductID                                        ProductName  \
# 0      10017413.0  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1      10016283.0  EthnoVogue Women Beige & Grey Made to Measure ...
# 2      10009781.0  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3      10015921.0  Raymond Men Blue Self-Design Single-Breasted B...
# 4      10017833.0  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...           ...                                                ...
# 12486  10262843.0  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487  10261721.0                 Mochi Women Gold-Toned Solid Heels
# 12488  10261607.0  612 league Girls Navy Blue & White Printed Reg...
# 12489  10266621.0  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490  10265199.0  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex         2774          7
# 1       EthnoVogue   Women         2774          7
# 2           SPYKAR   Women          899          7
# 3          Raymond     Men         2774          5
# 4             Parx     Men          759          5
# ...            ...     ...          ...        ...
# 12486   Pepe Jeans     Men         1299          7
# 12487        Mochi   Women         1990          5
# 12488   612 league   Girls          602          4
# 12489      Bvlgari     Men         2774          2
# 12490   Pepe Jeans     Men          799          5
#
#                                              Description PrimaryColor
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...         Blue
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
# [12491 rows x 8 columns]

# %% [markdown]
# ## **Construct Data**

# %% [markdown]
# membuat atau menghasilkan data baru dari data yang sudah ada dengan cara menggabungkan atau mengubah atribut (fitur) untuk mendapatkan informasi yang lebih bermakna.

# %% [markdown]
# ### 1. Rentang Harga
# Tujuan: Mengkategorikan harga produk ke dalam beberapa rentang untuk memudahkan analisis dan rekomendasi.

# %%
import pandas as pd

# Pastikan kolom 'Price (INR)' adalah numerik
df['Price (INR)'] = pd.to_numeric(df['Price (INR)'], errors='coerce')

# Hapus baris dengan nilai 'Price (INR)' yang tidak valid (NaN)
df.dropna(subset=['Price (INR)'], inplace=True)

# Buat kategori harga menggunakan pd.cut
df['Rentang_Harga'] = pd.cut(
    df['Price (INR)'],
    bins=[0, 5000, 10000, float('inf')],
    labels=['Murah', 'Sedang', 'Mahal']
)

# ---Change starts here---
# Create a mapping dictionary from 'Price (INR)' to 'Rentang_Harga'
price_to_rentang_harga = dict(zip(df['Price (INR)'], df['Rentang_Harga']))

# Map the 'Price (INR)' values to 'kategori_harga' using the dictionary
df['kategori_harga'] = df['Price (INR)'].map(price_to_rentang_harga)
# ---Change ends here---

# Tampilkan DataFrame dengan kolom yang relevan
result = df[['ProductID', 'ProductName', 'Price (INR)', 'Rentang_Harga']]
result.to_csv('produk_dengan_rentang_harga.csv', index=False)

df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex        11745          7
# 1       EthnoVogue   Women         5810          7
# 2           SPYKAR   Women          899          7
# 3          Raymond     Men         5599          5
# 4             Parx     Men          759          5
# ...            ...     ...          ...        ...
# 12486   Pepe Jeans     Men         1299          7
# 12487        Mochi   Women         1990          5
# 12488   612 league   Girls          602          4
# 12489      Bvlgari     Men         8950          2
# 12490   Pepe Jeans     Men          799          5
#
#                                              Description PrimaryColor  \
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
#       Rentang_Harga kategori_harga
# 0             Mahal          Mahal
# 1            Sedang         Sedang
# 2             Murah          Murah
# 3            Sedang         Sedang
# 4             Murah          Murah
# ...             ...            ...
# 12486         Murah          Murah
# 12487         Murah          Murah
# 12488         Murah          Murah
# 12489        Sedang         Sedang
# 12490         Murah          Murah
#
# [12491 rows x 10 columns]

# %% [markdown]
# ### 2. Popularitas Merek
# Tujuan: Menunjukkan tingkat popularitas merek berdasarkan frekuensi kemunculannya dalam dataset.

# %%
df
Brand_popularitas = df['ProductBrand'].value_counts().to_dict()
df['Popularitas_Brand'] = df['ProductBrand'].map(Brand_popularitas)
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  NumImages  \
# 0             DKNY  Unisex        11745          7
# 1       EthnoVogue   Women         5810          7
# 2           SPYKAR   Women          899          7
# 3          Raymond     Men         5599          5
# 4             Parx     Men          759          5
# ...            ...     ...          ...        ...
# 12486   Pepe Jeans     Men         1299          7
# 12487        Mochi   Women         1990          5
# 12488   612 league   Girls          602          4
# 12489      Bvlgari     Men         8950          2
# 12490   Pepe Jeans     Men          799          5
#
#                                              Description PrimaryColor  \
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
#       Rentang_Harga kategori_harga  Popularitas_Brand
# 0             Mahal          Mahal                 29
# 1            Sedang         Sedang                 23
# 2             Murah          Murah                 39
# 3            Sedang         Sedang                 63
# 4             Murah          Murah                154
# ...             ...            ...                ...
# 12486         Murah          Murah                340
# 12487         Murah          Murah                 27
# 12488         Murah          Murah                 16
# 12489        Sedang         Sedang                 11
# 12490         Murah          Murah                340
#
# [12491 rows x 11 columns]

# %% [markdown]
# ## **Data Reduction**

# %% [markdown]
# mengurangi volume data tanpa menghilangkan informasi penting. Tujuannya adalah untuk menyederhanakan analisis, menghemat ruang penyimpanan, dan mempercepat pemrosesan data. Disini saya menghapus kolom "NumImages"

# %%
df = df.drop('NumImages', axis=1)
df
# Out:
#        ProductID                                        ProductName  \
# 0       10017413  DKNY Unisex Black & Grey Printed Medium Trolle...
# 1       10016283  EthnoVogue Women Beige & Grey Made to Measure ...
# 2       10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...
# 3       10015921  Raymond Men Blue Self-Design Single-Breasted B...
# 4       10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...
# ...          ...                                                ...
# 12486   10262843  Pepe Jeans Men Black Hammock Slim Fit Low-Rise...
# 12487   10261721                 Mochi Women Gold-Toned Solid Heels
# 12488   10261607  612 league Girls Navy Blue & White Printed Reg...
# 12489   10266621  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...
# 12490   10265199  Pepe Jeans Men Black & Grey Striped Polo Colla...
#
#       ProductBrand  Gender  Price (INR)  \
# 0             DKNY  Unisex        11745
# 1       EthnoVogue   Women         5810
# 2           SPYKAR   Women          899
# 3          Raymond     Men         5599
# 4             Parx     Men          759
# ...            ...     ...          ...
# 12486   Pepe Jeans     Men         1299
# 12487        Mochi   Women         1990
# 12488   612 league   Girls          602
# 12489      Bvlgari     Men         8950
# 12490   Pepe Jeans     Men          799
#
#                                              Description PrimaryColor  \
# 0      Black and grey printed medium trolley bag, sec...        Black
# 1      Beige & Grey made to measure kurta with churid...        Beige
# 2      Pink coloured wash 5-pocket high-rise cropped ...         Pink
# 3      Blue self-design bandhgala suitBlue self-desig...         Blue
# 4      Brown and off-white printed casual shirt, has ...        White
# ...                                                  ...          ...
# 12486  Black dark wash 5-pocket low-rise jeans, clean...        Black
# 12487  A pair of gold-toned open toe heels, has regul...         Gold
# 12488  Navy Blue and White printed mid-rise denim sho...         Blue
# 12489  Bvlgari Men Aqva Pour Homme Marine Eau de Toil...          NaN
# 12490  Black and grey striped T-shirt, has a polo col...        Black
#
#       Rentang_Harga kategori_harga  Popularitas_Brand
# 0             Mahal          Mahal                 29
# 1            Sedang         Sedang                 23
# 2             Murah          Murah                 39
# 3            Sedang         Sedang                 63
# 4             Murah          Murah                154
# ...             ...            ...                ...
# 12486         Murah          Murah                340
# 12487         Murah          Murah                 27
# 12488         Murah          Murah                 16
# 12489        Sedang         Sedang                 11
# 12490         Murah          Murah                340
#
# [12491 rows x 10 columns]

# %% [markdown]
# # Matplotlib & Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df

df.head()
# Out:
#    ProductID                                        ProductName ProductBrand  \
# 0   10017413  DKNY Unisex Black & Grey Printed Medium Trolle...         DKNY
# 1   10016283  EthnoVogue Women Beige & Grey Made to Measure ...   EthnoVogue
# 2   10009781  SPYKAR Women Pink Alexa Super Skinny Fit High-...       SPYKAR
# 3   10015921  Raymond Men Blue Self-Design Single-Breasted B...      Raymond
# 4   10017833  Parx Men Brown & Off-White Slim Fit Printed Ca...         Parx
#
#    Gender  Price (INR)                                        Description  \
# 0  Unisex        11745  Black and grey printed medium trolley bag, sec...
# 1   Women         5810  Beige & Grey made to measure kurta with churid...
# 2   Women          899  Pink coloured wash 5-pocket high-rise cropped ...
# 3     Men         5599  Blue self-design bandhgala suitBlue self-desig...
# 4     Men          759  Brown and off-white printed casual shirt, has ...
#
#   PrimaryColor Rentang_Harga kategori_harga  Popularitas_Brand
# 0        Black         Mahal          Mahal                 29
# 1        Beige        Sedang         Sedang                 23
# 2         Pink         Murah          Murah                 39
# 3         Blue        Sedang         Sedang                 63
# 4        White         Murah          Murah                154

# %%
# Box Plot: Variasi harga berdasarkan merek
plt.figure(figsize=(12, 6))
top_brands = df['ProductBrand'].value_counts().index[:10]  # Ambil 10 merek teratas
sns.boxplot(x='ProductBrand', y='Price (INR)', data=df[df['ProductBrand'].isin(top_brands)])
plt.xticks(rotation=45)
plt.title('Variasi Harga Berdasarkan Merek')
plt.show()

# %% [markdown]
# **Insight :**
# - Setiap merek punya harga yang berbeda-beda. Puma dan GAP cenderung lebih mahal dibanding merek lain.
# - Flying Machine dan Pepe Jeans punya harga yang lebih stabil dan tidak banyak variasi.
#
# Jadi, merek tertentu punya harga lebih mahal dan bervariasi, sementara yang lain lebih stabil dan terjangkau.
#
# **Tindakan yang Dapat Diambil:**
# Karena saya sebagai penjuala yang ingin merekomendasikan produk, jadi :
# - Bisa menyesuaikan stok berdasarkan merek yang lebih stabil atau punya permintaan tinggi.

# %%
plt.figure(figsize=(12, 8))
top_brands = df[['ProductBrand', 'Popularitas_Brand']].drop_duplicates().nlargest(20, 'Popularitas_Brand')
sns.barplot(x='Popularitas_Brand', y='ProductBrand', data=top_brands, palette='viridis')
plt.title('Jumlah Produk per Merek (Top 20)')
plt.xlabel('Jumlah Produk')
plt.ylabel('Merek')
plt.show()
# Out:
# <ipython-input-42-4546ac26a76c>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Popularitas_Brand', y='ProductBrand', data=top_brands, palette='viridis')

# %% [markdown]
# **Insight:**
# - Indian Terrain, Puma, dan Pepe Jeans memiliki jumlah produk terbanyak, menunjukkan bahwa mereka memiliki banyak varian yang bisa ditawarkan kepada pelanggan.
# - DressBerry dan SEJ by Nisha Gupta memiliki jumlah produk paling sedikit, yang bisa berarti mereka lebih fokus pada kategori tertentu atau pasarnya masih berkembang.
#
# **Tindakan yang Dapat Diambil:**
# - Fokus pada Merek dengan Produk Terbanyak
# -Merek dengan produk sedikit bisa dijadikan sebagai pilihan eksklusif atau niche bagi pelanggan yang ingin sesuatu yang unik.

# %%
plt.figure(figsize=(12, 8))
avg_price_per_brand = df.groupby('ProductBrand')['Price (INR)'].mean().sort_values(ascending=False).head(20)
sns.barplot(x=avg_price_per_brand.values, y=avg_price_per_brand.index, palette='magma')
plt.title('Harga Rata-rata per Merek (Top 20)')
plt.xlabel('Harga Rata-rata (INR)')
plt.ylabel('Merek')
plt.show()
# Out:
# <ipython-input-32-c46f16bb96c5>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_per_brand.values, y=avg_price_per_brand.index, palette='magma')

# %% [markdown]
# **Insight:**
# - Garmin, MOVADO, dan Maserati memiliki harga rata-rata tertinggi, menunjukkan bahwa mereka termasuk dalam kategori produk premium atau mewah.
# -SEIKO, BERING, dan DKNY memiliki harga rata-rata yang lebih rendah dibanding merek premium, tetapi tetap dalam kategori menengah ke atas.
#
# **Tindakan yang Dapat Diambil:**
# - Menyediakan kategori produk berdasarkan rentang harga untuk memudahkan pelanggan memilih sesuai budget mereka.
# - Untuk merek premium, bisa menggunakan strategi pemasaran eksklusif seperti limited edition atau paket bundling dengan layanan tambahan.

# %%
# Bar Chart: Jumlah produk per merek dalam rentang harga tertentu
price_bins = pd.cut(df['Price (INR)'], bins=[0, 500, 1000, 2000, 5000, 10000], labels=['<500', '500-1000', '1000-2000', '2000-5000', '>5000'])
df['price_range'] = price_bins
brand_price_counts = df.groupby(['ProductBrand', 'price_range']).size().unstack().fillna(0)

brand_price_counts.loc[top_brands].plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Jumlah Produk per Merek dalam Rentang Harga')
plt.xlabel('Merek')
plt.ylabel('Jumlah Produk')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-33-1e3bf826c81c>:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   brand_price_counts = df.groupby(['ProductBrand', 'price_range']).size().unstack().fillna(0)

# %% [markdown]
# **Insight:**
#
# -Indian Terrain Mendominasi Pasar Produk Harga Menengah
# - Puma Memiliki Produk Premium Lebih Banyak
#
# **Tindakan yang Dapat Diambil:**
#
# - Jika ingin menjual produk dalam jumlah besar dengan harga terjangkau, Indian Terrain bisa menjadi fokus utama karena memiliki stok terbanyak dalam kategori harga rendah hingga menengah.
# - Jika ingin menjual produk eksklusif dengan margin lebih tinggi, Puma bisa dijadikan andalan karena memiliki banyak produk premium.

# %% [markdown]
# ## Membuat Rekomendasi 10 top brands berdasarkan harga

# %%
def visualize_recommendations(df, price_category, top_n=10):
    # Filter data berdasarkan kategori harga dan merek teratas
    recommended = df[(df['Rentang_Harga'] == price_category) & (df['ProductBrand'].isin(top_20_brands))]
    recommended = recommended[['ProductBrand', 'ProductName', 'Price (INR)']].sort_values(by='Price (INR)').head(top_n)

    # Plot visualisasi
    plt.figure(figsize=(12, 6))
    sns.barplot(
        data=recommended,
        x='Price (INR)',
        y='ProductName',
        hue='ProductBrand',
        dodge=False
    )

    plt.xlabel("Harga (INR)")
    plt.ylabel("Produk")
    plt.title(f"Rekomendasi Produk untuk Kategori Harga {price_category}")
    plt.legend(title="Merek")
    plt.show()


visualize_recommendations(df, 'Murah')

# %%
def visualize_recommendations(df, price_category, top_n=10):
    # Filter data berdasarkan kategori harga
    recommended = df[df['Rentang_Harga'] == price_category]
    recommended = recommended[['ProductBrand', 'ProductName', 'Price (INR)']].sort_values(by='Price (INR)').head(top_n)

    # Plot visualisasi
    plt.figure(figsize=(10, 5))
    sns.barplot(data=recommended, x='Price (INR)', y='ProductName', hue='ProductBrand', dodge=False)

    plt.xlabel("Harga (INR)")
    plt.ylabel("Produk")
    plt.title(f"Rekomendasi Produk untuk Kategori Harga {price_category}")
    plt.legend(title="Merek")
    plt.show()

# Menampilkan rekomendasi untuk kategori "Murah"
visualize_recommendations(df, 'Murah')

# %%
visualize_recommendations(df, 'Sedang')

# %%
visualize_recommendations(df, 'Mahal')
